# %%
## Description for each of the columns in the Dataset

N - ratio of Nitrogen content in soil
P - ratio of Phosphorous content in soil
K - ration of Potassium content in soil
temperature - temperature in degree Celsius
humidity - relative humidity in %
ph - ph value of the soil
rainfall - rainfall in mm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('data.xlsx')

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# checking null value

# %%
df=data.copy()

# %%
df.isnull().sum() # No null value
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Checking ave# lets check the Summary for all the crops
print('Average Ratio of Nitrogen in the Soil: ',data['N'].mean())
print('Average Ratio of Phosphorous in the Soil: ',data['P'].mean())
print('Average Ratio of Potassium in the Soil: ',data['K'].mean())
print('Average Tempature in Celsius: ',data['temperature'].mean())
print('Average Relative Humidity in %: ',data['humidity'].mean())
print('Average PH Value of the soil: ',data['ph'].mean())
print('Average Rainfall in mm: ',data['rainfall'].mean())
# Out:
# Average Ratio of Nitrogen in the Soil:  50.551818181818184
# Average Ratio of Phosphorous in the Soil:  53.36272727272727
# Average Ratio of Potassium in the Soil:  48.14909090909091
# Average Tempature in Celsius:  25.616243851779533
# Average Relative Humidity in %:  71.48177921778648
# Average PH Value of the soil:  6.469480065256367
# Average Rainfall in mm:  103.46365541576829

# %%
# Checking unique value

# %%
column=list(df.columns) # No unique value

# %%
for column in column:
    print(f'{column}:{df[column].unique}')
# Out:
# N:<bound method Series.unique of 0        90
# 1        85
# 2        60
# 3        74
# 4        78
#        ...
# 2195    107
# 2196     99
# 2197    118
# 2198    117
# 2199    104
# Name: N, Length: 2200, dtype: int64>
# P:<bound method Series.unique of 0       42
# 1       58
# 2       55
# 3       35
# 4       42
#         ..
# 2195    34
# 2196    15
# 2197    33
# 2198    32
# 2199    18
# Name: P, Length: 2200, dtype: int64>
# K:<bound method Series.unique of 0       43
# 1       41
# 2       44
# 3       40
# 4       42
#         ..
# 2195    32
# 2196    27
# 2197    30
# 2198    34
# 2199    30
# Name: K, Length: 2200, dtype: int64>
# temperature:<bound method Series.unique of 0       20.879744
# 1       21.770462
# 2       23.004459
# 3       26.491096
# 4       20.130175
#           ...
# 2195    26.774637
# 2196    27.417112
# 2197    24.131797
# 2198    26.272418
# 2199    23.603016
# Name: temperature, Length: 2200, dtype: float64>
# ...

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df_col=list(df.select_dtypes(exclude=object))

# %%
df_col
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# %%
# EDA Part

# %%
# Ploting graph

# %%
for i in range(len(df_col)):
    plt.subplot(3,3,i+1)
    sns.countplot(df[df_col[i]])
# Out:
# Error in callback <function flush_figures at 0x000001FB35B861F0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\.dotnet\ANACONDA\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# ~\.dotnet\ANACONDA\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['N'],df['label'])
plt.xlabel('Ratio of Nitrogen')
# Out:
# Text(0.5, 0, 'Ratio of Nitrogen')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['rainfall'],df['label'])
plt.xlabel('rainfall')
# Out:
# Text(0.5, 0, 'rainfall')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['ph'],df['label'])
plt.xlabel('ph of soil')
# Out:
# Text(0.5, 0, 'ph of soil')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['humidity'],df['label'])
plt.xlabel('Humidity')
# Out:
# Text(0.5, 0, 'Humidity')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['temperature'],df['label'])
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['K'],df['label'])
plt.xlabel('Ratio of Potassium')
# Out:
# Text(0.5, 0, 'Ratio of Potassium')

# %%
plt.figure(figsize=(10,15))
plt.subplot(2, 4, 1)
sns.barplot(df['P'],df['label'])
plt.xlabel('Ratio of Phosphorous')
# Out:
# Text(0.5, 0, 'Ratio of Phosphorous')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
### Lets check the distribution of Agricultural Conditions

plt.rcParams['figure.figsize'] = (15, 7)

plt.subplot(2, 4, 1)
sns.distplot(data['N'], color = 'lightgrey')
plt.xlabel('Ratio of Nitrogen', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 2)
sns.distplot(data['P'], color = 'skyblue')
plt.xlabel('Ratio of Phosphorous', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 3)
sns.distplot(data['K'], color ='darkblue')
plt.xlabel('Ratio of Potassium', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 4)
sns.distplot(data['temperature'], color = 'black')
plt.xlabel('Temperature', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 5)
sns.distplot(data['rainfall'], color = 'grey')
plt.xlabel('Rainfall', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 6)
sns.distplot(data['humidity'], color = 'lightgreen')
plt.xlabel('Humidity', fontsize = 12)
plt.grid()

plt.subplot(2, 4, 7)
sns.distplot(data['ph'], color = 'darkgreen')
plt.xlabel('pH Level', fontsize = 12)
plt.grid()

plt.suptitle('Distribution for Agricultural Conditions', fontsize = 20)
plt.show()

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
# label  encoding

# %%
df['label'].replace({'pomegranate':1, 'kidneybeans':1, 'lentil':1, 'chickpea':1,'blackgram':1, 'orange':1, 'mango':1, 'mothbeans':1, 'mungbean':1},inplace=True)
df['label'].replace({'grapes':2, 'apple':2},inplace=True)
df['label'].replace({'cotton':3, 'banana':3, 'maize':3, 'watermelon':3, 'muskmelon':3},inplace=True)
df['label'].replace({'jute':4, 'coconut':4, 'papaya':4, 'rice':4, 'coffee':4, 'pigeonpeas':4},inplace=True)

# %%
df['label'].value_counts()
# Out:
# 1    900
# 4    600
# 3    500
# 2    200
# Name: label, dtype: int64

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536      4
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537      4
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248      4
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034      4
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340      4

# %%
### Predictive Modelling

# %%
# lets split the Dataset for Predictive Modelling

y = df['label']
x = df.drop(['label'], axis = 1)

print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler
scaler=StandardScaler()
scaler
X_scaled=scaler.fit_transform(x)

# %%
print("The Shape of x train:", x_train.shape)
print("The Shape of x test:", x_test.shape)
print("The Shape of y train:", y_train.shape)
print("The Shape of y test:", y_test.shape)
# Out:
# The Shape of x train: (1760, 7)
# The Shape of x test: (440, 7)
# The Shape of y train: (1760,)
# The Shape of y test: (440,)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,roc_auc_score

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
model=lr.fit(x_train,y_train)

# %%
model
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[180   0   0  11]
#  [  0  36   0   0]
#  [  0   0  89   3]
#  [ 10   0   4 107]]

# %%
CR=classification_report(y_test,y_pred)

# %%
print(CR)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.94      0.94       191
#            2       1.00      1.00      1.00        36
#            3       0.96      0.97      0.96        92
#            4       0.88      0.88      0.88       121
#
#     accuracy                           0.94       440
#    macro avg       0.95      0.95      0.95       440
# weighted avg       0.94      0.94      0.94       440

# %%
# Real time prediction

# %%
prediction = model.predict((np.array([[90,
                                       40,
                                       40,
                                       20,
                                       80,
                                       7,
                                       200]])))
print("The Suggested Crop for Given Climatic Condition is :", prediction) # for rice
# Out:
# The Suggested Crop for Given Climatic Condition is : [4]

# %%
prediction = model.predict((np.array([[20,
                                       30,
                                       10,
                                       15,
                                       90,
                                       7.5,
                                       100]])))
print("The Suggested Crop for Given Climatic Condition is :", prediction)
# Out:
# The Suggested Crop for Given Climatic Condition is : [1]
